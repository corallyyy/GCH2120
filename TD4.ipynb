# %% [markdown]
# ## TD 4
# ### Corally Ngov (2392143) et Lina Sadat (2378349)
# ---

# %% [markdown]
# ### i)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.optimize import fsolve
from scipy.integrate import solve_ivp

# %%
def bilans(t, x, p, u):
    # Assignation des variables d’etat
    [Ca, Cb, Cc, T] = x

    # Assignation des parametres
    [rho, Cp, V, A1, A2, E1R, E2R, dH1, dH2, Tc, UA] = p

    # Assignation des variables manipulees
    [F, Cain, Tin, Tc] = u

    k1 = A1 * np.exp(-E1R / T)
    k2 = A2 * np.exp(-E2R / T)
    # Systeme d’equations differentielles
    dCadt = (F / V) * (Cain - Ca) - (k1 * Ca)
    dCbdt = (-F / V) * Cb + (k1 * Ca) - (k2 * Cb)
    dCcdt = (-F / V) * Cc + (k2 * Cb)
    dTdt = (F / V) * (Tin - T) - (1 / (rho * Cp)) * ((k1 * Ca * dH1) + (k2 * Cb * dH2)) - (UA / (rho * V * Cp)) * (T - Tc)
    return [dCadt, dCbdt, dCcdt, dTdt]

#Conditions initiales
p = [1.0, 4.18, 60, 2.53e9, 7.34e10, 7500, 9500, -71.9, 33.1, 313, 85]
t_sim = [0, 100] #en min
u0 = [10, 7.5, 293, 313]
x0=[2, 0, 0, 293]
x0 = fsolve(lambda x, p, u: bilans(0, x, p, u), x0, args=(p, u0))

sim = solve_ivp(bilans, t_sim, x0, method = 'RK45', args = (p, u0), max_step = 0.01)

Ca, Cb, Cc, T = sim.y

#Valeurs en regime permanent
print('Valeurs en regime permanent :')
print(f'CA = {Ca[-1]:.2f} mol/L')
print(f'CB = {Cb[-1]:.2f} mol/L')
print(f'CC = {Cc[-1]:.2f} mol/L')
print(f'T = {T[-1]:.2f} K')
# Out:
# Valeurs en regime permanent :
# CA = 1.88 mol/L
# CB = 4.59 mol/L
# CC = 1.03 mol/L
# T = 335.59 K

# %%
#Fichier script permettant d’´evaluer les matrices A et B
#aux conditions de regime permanent
#Definition des variables symboliques
Ca, Cb, Cc, T = sp.symbols('Ca Cb Cc T')
F, Cain, Tin, Tc = sp.symbols('F Cain Tin Tc')
rho, Cp, V, A1, A2, E1R, E2R, dH1, dH2, UA = sp.symbols('rho Cp V A1 A2 E1R E2R dH1 dH2 UA')

k1 = A1*sp.exp(-E1R/T)
k2 = A2*sp.exp(-E2R/T)

#Systeme d’equations differentielles
dCadt = (F/V)*(Cain-Ca)- (k1*Ca)
dCbdt = (-F/V)*Cb + (k1*Ca)- (k2*Cb)
dCcdt = (-F/V)*Cc + (k2*Cb)
dTdt = (F/V)*(Tin-T)- (1/(rho*Cp))*((k1*Ca*dH1) + (k2*Cb*dH2))- (UA/(rho*V*Cp))*(T-Tc)

f = sp.Matrix([dCadt, dCbdt, dCcdt, dTdt])
x = sp.Matrix([Ca, Cb, Cc, T])
u = sp.Matrix([F, Tin, Cain, Tc])

#Calcul symbolique des matrices A et B
mat_A = sp.simplify(f.jacobian(x))
mat_B = sp.simplify(f.jacobian(u))

print("Matrice A- symbolique =")
sp.pprint(mat_A)

print("Matrice B- symbolique =")
sp.pprint(mat_B)

#Calcul numerique des matrices A et B
#Entrez ici vos valeurs des variables d’etat en regime permanent obtenues a l’aide de la fonction fsolve a la question i).
valeurs_num = {
 Ca: Ca, Cb: Cb, Cc: Cc, T: T,
 F: 10.0, Cain: 7.5, Tin: 293, Tc: 313,
 rho: 1.0, Cp: 4.18, V: 60,
 A1: 2.53*10**9, A2: 7.34*10**10, E1R: 7500, E2R: 9500,
 dH1:-71.9, dH2: 33.1, UA: 85
 }

mat_A_num = mat_A.subs(valeurs_num).evalf()
mat_B_num = mat_B.subs(valeurs_num).evalf()

print("Matrice A- num´erique =")
sp.pprint(mat_A_num)

print("Matrice B- num´erique =")
sp.pprint(mat_B_num)
# Out:
# Matrice A- symbolique =
# ⎡                                                                       -E1R   ↪
# ⎢      -E1R                                                             ─────  ↪
# ⎢      ─────                                                              T    ↪
# ⎢        T     F                                            -A₁⋅Ca⋅E1R⋅ℯ       ↪
# ⎢- A₁⋅ℯ      - ─         0          0                       ────────────────── ↪
# ⎢              V                                                     2         ↪
# ⎢                                                                   T          ↪
# ⎢                                                                              ↪
# ⎢                                                             -E1R             ↪
# ⎢       -E1R            -E2R                                  ─────            ↪
# ⎢       ─────           ─────                                   T              ↪
# ⎢         T               T     F                  A₁⋅Ca⋅E1R⋅ℯ        A₂⋅Cb⋅E2 ↪
# ⎢   A₁⋅ℯ          - A₂⋅ℯ      - ─   0              ──────────────── - ──────── ↪
# ⎢                               V                          2                   ↪
# ⎢                                                         T                  T ↪
# ⎢                                                                              ↪
# ⎢                                                                       -E2R   ↪
# ⎢                        -E2R                                           ─────  ↪
# ⎢                        ─────                                            T    ↪
# ⎢                          T       -F                        A₂⋅Cb⋅E2R⋅ℯ       ↪
# ⎢       0            A₂⋅ℯ          ───                       ────────────────  ↪
# ⎢                                   V                                2         ↪
# ⎢                                                                   T          ↪
# ⎢                                                                              ↪
# ⎢         -E1R             -E2R                          -E1R                  ↪
# ⎢         ─────            ─────                         ─────                 ↪
# ⎢           T                T                             T                   ↪
# ⎢-A₁⋅dH₁⋅ℯ        -A₂⋅dH₂⋅ℯ               A₁⋅Ca⋅E1R⋅dH₁⋅ℯ        A₂⋅Cb⋅E2R⋅dH₂ ↪
# ⎢───────────────  ───────────────   0   - ──────────────────── - ───────────── ↪
# ⎢     Cp⋅ρ             Cp⋅ρ                         2                      2   ↪
# ⎣                                               Cp⋅T ⋅ρ                Cp⋅T ⋅ρ ↪
#
# ↪                     ⎤
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪    -E2R             ⎥
# ↪    ─────            ⎥
# ↪      T              ⎥
# ↪ R⋅ℯ                 ⎥
# ↪ ────────            ⎥
# ↪ 2                   ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪                     ⎥
# ↪   -E2R              ⎥
# ↪   ─────             ⎥
# ↪     T               ⎥
# ↪ ⋅ℯ        F     UA  ⎥
# ↪ ─────── - ─ - ──────⎥
# ↪           V   Cp⋅V⋅ρ⎥
# ↪                     ⎦
# Matrice B- symbolique =
# ⎡-Ca + Cain     F        ⎤
# ⎢──────────  0  ─    0   ⎥
# ⎢    V          V        ⎥
# ⎢                        ⎥
# ⎢   -Cb                  ⎥
# ⎢   ────     0  0    0   ⎥
# ⎢    V                   ⎥
# ⎢                        ⎥
# ⎢   -Cc                  ⎥
# ⎢   ────     0  0    0   ⎥
# ⎢    V                   ⎥
# ⎢                        ⎥
# ⎢ -T + Tin   F       UA  ⎥
# ⎢ ────────   ─  0  ──────⎥
# ⎣    V       V     Cp⋅V⋅ρ⎦
# Matrice A- num´erique =
# ⎡                                                                              ↪
# ⎢                                   -7500                                      ↪
# ⎢                                   ──────                                     ↪
# ⎢                                     T                                        ↪
# ⎢-0.166666666666667 - 2530000000.0⋅ℯ                            0              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                        -7500                                                 ↪
# ⎢                        ──────                                                ↪
# ⎢                          T                                                   ↪
# ⎢          2530000000.0⋅ℯ                   -0.166666666666667 - 73400000000.0 ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                    -9500     ↪
# ⎢                                                                    ──────    ↪
# ⎢                                                                      T       ↪
# ⎢                    0                                73400000000.0⋅ℯ          ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                          -7500                                       -9500   ↪
# ⎢                          ──────                                      ──────  ↪
# ⎢                            T                                           T     ↪
# ⎢        43518421052.6316⋅ℯ                          -581229665071.77⋅ℯ        ↪
# ⎢                                                                              ↪
# ⎣                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                         -18975000000000.0⋅Ca ↪
# ↪                   0                                     ──────────────────── ↪
# ↪                                                                       2      ↪
# ↪                                                                      T       ↪
# ↪                                                                              ↪
# ↪                                                                -7500         ↪
# ↪   -9500                                                        ──────        ↪
# ↪   ──────                                                         T           ↪
# ↪     T                                     18975000000000.0⋅Ca⋅ℯ         6973 ↪
# ↪ ⋅ℯ                0                       ─────────────────────────── - ──── ↪
# ↪                                                        2                     ↪
# ↪                                                       T                      ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                          697300000000000.0⋅C ↪
# ↪           -0.166666666666667                             ─────────────────── ↪
# ↪                                                                        2     ↪
# ↪                                                                       T      ↪
# ↪                                                                              ↪
# ↪                                                     -7500                    ↪
# ↪                                                     ──────                   ↪
# ↪                                                       T                      ↪
# ↪                               326388157894737.0⋅Ca⋅ℯ         5.5216818181818 ↪
# ↪                   0           ──────────────────────────── - ─────────────── ↪
# ↪                                             2                                ↪
# ↪                                            T                               T ↪
#
# ↪   -7500                             ⎤
# ↪   ──────                            ⎥
# ↪     T                               ⎥
# ↪ ⋅ℯ                                  ⎥
# ↪ ─────────                           ⎥
# ↪                                     ⎥
# ↪                                     ⎥
# ↪                                     ⎥
# ↪                   -9500             ⎥
# ↪                   ──────            ⎥
# ↪                     T               ⎥
# ↪ 00000000000.0⋅Cb⋅ℯ                  ⎥
# ↪ ────────────────────────            ⎥
# ↪           2                         ⎥
# ↪          T                          ⎥
# ↪                                     ⎥
# ↪    -9500                            ⎥
# ↪    ──────                           ⎥
# ↪      T                              ⎥
# ↪ b⋅ℯ                                 ⎥
# ↪ ─────────                           ⎥
# ↪                                     ⎥
# ↪                                     ⎥
# ↪                                     ⎥
# ↪           -9500                     ⎥
# ↪           ──────                    ⎥
# ↪             T                       ⎥
# ↪ 2e+15⋅Cb⋅ℯ                          ⎥
# ↪ ──────────────── - 0.505582137161085⎥
# ↪ 2                                   ⎥
# ↪                                     ⎦
# Matrice B- num´erique =
# ⎡     0.125 - 0.0166666666666667⋅Ca               0          0.166666666666667 ↪
# ⎢                                                                              ↪
# ⎢        -0.0166666666666667⋅Cb                   0                  0         ↪
# ⎢                                                                              ↪
# ⎢        -0.0166666666666667⋅Cc                   0                  0         ↪
# ⎢                                                                              ↪
# ⎣4.88333333333333 - 0.0166666666666667⋅T  0.166666666666667          0         ↪
#
# ↪           0        ⎤
# ↪                    ⎥
# ↪           0        ⎥
# ↪                    ⎥
# ↪           0        ⎥
# ↪                    ⎥
# ↪   0.338915470494418⎦

# %% [markdown]
# ### ii)

# %%
valeurs_propres = mat_A.eigenvals()
print("Valeurs propres de A = ")
sp.pprint(valeurs_propres)
# Out:
# Valeurs propres de A =
# ⎧                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                         -E1R        -E1R                   -E2R        -E2R  ↪
# ⎪                         ─────       ─────                  ─────       ───── ↪
# ⎪                           T           T                      T           T   ↪
# ⎪-F        A₁⋅Ca⋅E1R⋅dH₁⋅ℯ        A₁⋅ℯ        A₂⋅Cb⋅E2R⋅dH₂⋅ℯ        A₂⋅ℯ      ↪
# ⎨───: 1, - ──────────────────── - ───────── - ──────────────────── - ───────── ↪
# ⎪ V                   2               3                  2               3     ↪
# ⎪               3⋅Cp⋅T ⋅ρ                          3⋅Cp⋅T ⋅ρ                   ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎪                                                                              ↪
# ⎩                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪    F                                                                         ↪
# ↪  - ─ - ───────────────────────────────────────────────────────────────────── ↪
# ↪    V                   _____________________________________________________ ↪
# ↪                       ╱                                                      ↪
# ↪                      ╱                                                       ↪
# ↪                     ╱                                                        ↪
# ↪                    ╱                                                         ↪
# ↪                   ╱                                                          ↪
# ↪                  ╱                                                           ↪
# ↪                 ╱                              -E1R   -E2R                   ↪
# ↪                ╱                               ─────  ─────                  ↪
# ↪               ╱                                  T      T                    ↪
# ↪              ╱          27⋅A₁⋅A₂⋅Ca⋅E1R⋅F⋅dH₁⋅ℯ     ⋅ℯ        27⋅A₁⋅A₂⋅Ca⋅E1 ↪
# ↪        3⋅   ╱           ─────────────────────────────────── + ────────────── ↪
# ↪          3 ╱                              2                                  ↪
# ↪          ╲╱                         2⋅Cp⋅T ⋅V⋅ρ                           2⋅ ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          -E1R   -E2R                           -E1R   -E2R                -E ↪
# ↪          ─────  ─────                          ─────  ─────               ── ↪
# ↪            T      T                              T      T                    ↪
# ↪ R⋅F⋅dH₂⋅ℯ     ⋅ℯ        27⋅A₁⋅A₂⋅Cb⋅E2R⋅F⋅dH₂⋅ℯ     ⋅ℯ        27⋅A₁⋅A₂⋅F⋅ℯ   ↪
# ↪ ───────────────────── + ─────────────────────────────────── + ────────────── ↪
# ↪     2                                     2                             2⋅V  ↪
# ↪ Cp⋅T ⋅V⋅ρ                           2⋅Cp⋅T ⋅V⋅ρ                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ 1R   -E2R                 -E1R   -E2R                         -E1R           ↪
# ↪ ───  ─────                ─────  ─────                        ─────          ↪
# ↪ T      T                    T      T                   2        T            ↪
# ↪    ⋅ℯ        27⋅A₁⋅A₂⋅UA⋅ℯ     ⋅ℯ        27⋅A₁⋅Ca⋅E1R⋅F ⋅dH₁⋅ℯ        27⋅A₁⋅ ↪
# ↪ ────────── + ───────────────────────── + ────────────────────────── + ────── ↪
# ↪                      2⋅Cp⋅V⋅ρ                         2  2                   ↪
# ↪                                                 2⋅Cp⋅T ⋅V ⋅ρ               2 ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪     -E1R                -E1R                         -E2R              -E2R  ↪
# ↪     ─────               ─────                        ─────             ───── ↪
# ↪  2    T                   T                   2        T            2    T   ↪
# ↪ F ⋅ℯ        27⋅A₁⋅F⋅UA⋅ℯ        27⋅A₂⋅Cb⋅E2R⋅F ⋅dH₂⋅ℯ        27⋅A₂⋅F ⋅ℯ      ↪
# ↪ ───────── + ───────────────── + ────────────────────────── + ─────────────── ↪
# ↪   2                   2                      2  2                    2       ↪
# ↪ ⋅V              2⋅Cp⋅V ⋅ρ              2⋅Cp⋅T ⋅V ⋅ρ               2⋅V        ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                          ___________________________________ ↪
# ↪                                         ╱                                    ↪
# ↪                                        ╱      ⎛                              ↪
# ↪                                       ╱       ⎜                      -E1R    ↪
# ↪                                      ╱        ⎜                      ─────   ↪
# ↪                                     ╱         ⎜                        T     ↪
# ↪                -E2R                ╱          ⎜  3⋅A₁⋅A₂⋅Ca⋅E1R⋅dH₁⋅ℯ     ⋅ℯ ↪
# ↪                ─────              ╱       - 4⋅⎜- ─────────────────────────── ↪
# ↪                  T         3     ╱            ⎜                  2           ↪
# ↪    27⋅A₂⋅F⋅UA⋅ℯ        27⋅F    ╲╱             ⎝              Cp⋅T ⋅ρ         ↪
# ↪  + ───────────────── + ───── + ───────────────────────────────────────────── ↪
# ↪              2            3                                                  ↪
# ↪        2⋅Cp⋅V ⋅ρ       2⋅V                                                   ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ -E2R                        -E1R   -E2R                        -E1R   -E2R   ↪
# ↪ ─────                       ─────  ─────                       ─────  ─────  ↪
# ↪   T                           T      T                           T      T    ↪
# ↪         3⋅A₁⋅A₂⋅Ca⋅E1R⋅dH₂⋅ℯ     ⋅ℯ        3⋅A₁⋅A₂⋅Cb⋅E2R⋅dH₂⋅ℯ     ⋅ℯ       ↪
# ↪ ───── - ──────────────────────────────── - ────────────────────────────────  ↪
# ↪                         2                                  2                 ↪
# ↪                     Cp⋅T ⋅ρ                            Cp⋅T ⋅ρ               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                              -E1R            -E1R            ↪
# ↪            -E1R   -E2R                       ─────           ─────           ↪
# ↪            ─────  ─────                        T               T             ↪
# ↪              T      T     6⋅A₁⋅Ca⋅E1R⋅F⋅dH₁⋅ℯ        6⋅A₁⋅F⋅ℯ        3⋅A₁⋅UA ↪
# ↪ - 3⋅A₁⋅A₂⋅ℯ     ⋅ℯ      - ──────────────────────── - ───────────── - ─────── ↪
# ↪                                      2                     V             Cp⋅ ↪
# ↪                                  Cp⋅T ⋅V⋅ρ                                   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪   -E1R                       -E2R            -E2R             -E2R           ↪
# ↪   ─────                      ─────           ─────            ─────          ↪
# ↪     T                          T               T                T        2   ↪
# ↪ ⋅ℯ        6⋅A₂⋅Cb⋅E2R⋅F⋅dH₂⋅ℯ        6⋅A₂⋅F⋅ℯ        3⋅A₂⋅UA⋅ℯ        9⋅F    ↪
# ↪ ─────── - ──────────────────────── - ───────────── - ────────────── - ──── + ↪
# ↪ V⋅ρ                  2                     V             Cp⋅V⋅ρ         2    ↪
# ↪                  Cp⋅T ⋅V⋅ρ                                             V     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪  ⎛               -E1R                               -E2R                     ↪
# ↪  ⎜               ─────       -E1R                   ─────       -E2R         ↪
# ↪  ⎜                 T         ─────                    T         ─────        ↪
# ↪  ⎜A₁⋅Ca⋅E1R⋅dH₁⋅ℯ              T     A₂⋅Cb⋅E2R⋅dH₂⋅ℯ              T     3⋅F  ↪
# ↪  ⎜──────────────────── + A₁⋅ℯ      + ──────────────────── + A₂⋅ℯ      + ───  ↪
# ↪  ⎜          2                                  2                         V   ↪
# ↪  ⎝      Cp⋅T ⋅ρ                            Cp⋅T ⋅ρ                           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                      3                                                       ↪
# ↪          2          ⎞    ⎛                                                   ↪
# ↪         ⎞           ⎟    ⎜                       -E1R   -E2R                 ↪
# ↪         ⎟           ⎟    ⎜                       ─────  ─────                ↪
# ↪         ⎟           ⎟    ⎜                         T      T                  ↪
# ↪     UA  ⎟    6⋅F⋅UA ⎟    ⎜27⋅A₁⋅A₂⋅Ca⋅E1R⋅F⋅dH₁⋅ℯ     ⋅ℯ        27⋅A₁⋅A₂⋅Ca⋅ ↪
# ↪ + ──────⎟  - ───────⎟  + ⎜─────────────────────────────────── + ──────────── ↪
# ↪   Cp⋅V⋅ρ⎟        2  ⎟    ⎜                 2                                 ↪
# ↪         ⎠    Cp⋅V ⋅ρ⎠    ⎝             Cp⋅T ⋅V⋅ρ                             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                   -E1R   -E2R                ↪
# ↪                                                   ─────  ─────               ↪
# ↪                                                     T      T                 ↪
# ↪                               3⋅A₁⋅A₂⋅Ca⋅E1R⋅dH₁⋅ℯ     ⋅ℯ        3⋅A₁⋅A₂⋅Ca⋅ ↪
# ↪                             - ──────────────────────────────── - ─────────── ↪
# ↪                                               2                              ↪
# ↪                                           Cp⋅T ⋅ρ                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪            -E1R   -E2R                           -E1R   -E2R                 ↪
# ↪            ─────  ─────                          ─────  ─────                ↪
# ↪              T      T                              T      T                  ↪
# ↪ E1R⋅F⋅dH₂⋅ℯ     ⋅ℯ        27⋅A₁⋅A₂⋅Cb⋅E2R⋅F⋅dH₂⋅ℯ     ⋅ℯ        27⋅A₁⋅A₂⋅F⋅ℯ ↪
# ↪ ─────────────────────── + ─────────────────────────────────── + ──────────── ↪
# ↪      2                                     2                               V ↪
# ↪  Cp⋅T ⋅V⋅ρ                             Cp⋅T ⋅V⋅ρ                             ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          -E1R   -E2R                        -E1R   -E2R                      ↪
# ↪          ─────  ─────                       ─────  ─────            -E1R   - ↪
# ↪            T      T                           T      T              ─────  ─ ↪
# ↪ E1R⋅dH₂⋅ℯ     ⋅ℯ        3⋅A₁⋅A₂⋅Cb⋅E2R⋅dH₂⋅ℯ     ⋅ℯ                   T      ↪
# ↪ ───────────────────── - ──────────────────────────────── - 3⋅A₁⋅A₂⋅ℯ     ⋅ℯ  ↪
# ↪      2                                  2                                    ↪
# ↪  Cp⋅T ⋅ρ                            Cp⋅T ⋅ρ                                  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ -E1R   -E2R                 -E1R   -E2R                         -E1R         ↪
# ↪ ─────  ─────                ─────  ─────                        ─────        ↪
# ↪   T      T                    T      T                   2        T          ↪
# ↪      ⋅ℯ        27⋅A₁⋅A₂⋅UA⋅ℯ     ⋅ℯ        27⋅A₁⋅Ca⋅E1R⋅F ⋅dH₁⋅ℯ        27⋅A ↪
# ↪ ──────────── + ───────────────────────── + ────────────────────────── + ──── ↪
# ↪                         Cp⋅V⋅ρ                         2  2                  ↪
# ↪                                                    Cp⋅T ⋅V ⋅ρ                ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                    2         ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                           -E1R            -E1R             -E1R              ↪
# ↪ E2R                       ─────           ─────            ─────             ↪
# ↪ ────                        T               T                T               ↪
# ↪  T     6⋅A₁⋅Ca⋅E1R⋅F⋅dH₁⋅ℯ        6⋅A₁⋅F⋅ℯ        3⋅A₁⋅UA⋅ℯ        6⋅A₂⋅Cb⋅E ↪
# ↪      - ──────────────────────── - ───────────── - ────────────── - ───────── ↪
# ↪                   2                     V             Cp⋅V⋅ρ                 ↪
# ↪               Cp⋅T ⋅V⋅ρ                                                   Cp ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪       -E1R                -E1R                         -E2R              -E2 ↪
# ↪       ─────               ─────                        ─────             ─── ↪
# ↪    2    T                   T                   2        T            2    T ↪
# ↪ ₁⋅F ⋅ℯ        27⋅A₁⋅F⋅UA⋅ℯ        27⋅A₂⋅Cb⋅E2R⋅F ⋅dH₂⋅ℯ        27⋅A₂⋅F ⋅ℯ    ↪
# ↪ ─────────── + ───────────────── + ────────────────────────── + ───────────── ↪
# ↪    2                   2                      2  2                    2      ↪
# ↪   V                Cp⋅V ⋅ρ                Cp⋅T ⋅V ⋅ρ                 V       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪           -E2R            -E2R             -E2R           ⎛               -E ↪
# ↪           ─────           ─────            ─────          ⎜               ── ↪
# ↪             T               T                T        2   ⎜                  ↪
# ↪ 2R⋅F⋅dH₂⋅ℯ        6⋅A₂⋅F⋅ℯ        3⋅A₂⋅UA⋅ℯ        9⋅F    ⎜A₁⋅Ca⋅E1R⋅dH₁⋅ℯ   ↪
# ↪ ─────────────── - ───────────── - ────────────── - ──── + ⎜───────────────── ↪
# ↪   2                     V             Cp⋅V⋅ρ         2    ⎜          2       ↪
# ↪ ⋅T ⋅V⋅ρ                                             V     ⎝      Cp⋅T ⋅ρ     ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ R                -E2R              ⎛               -E1R                      ↪
# ↪ ──               ─────             ⎜               ─────       -E1R          ↪
# ↪                    T         3     ⎜                 T         ─────         ↪
# ↪      27⋅A₂⋅F⋅UA⋅ℯ        27⋅F      ⎜A₁⋅Ca⋅E1R⋅dH₁⋅ℯ              T     A₂⋅Cb ↪
# ↪ ── + ───────────────── + ───── + 2⋅⎜──────────────────── + A₁⋅ℯ      + ───── ↪
# ↪               2            3       ⎜          2                              ↪
# ↪           Cp⋅V ⋅ρ         V        ⎝      Cp⋅T ⋅ρ                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                   2          ↪
# ↪ 1R                               -E2R                            ⎞           ↪
# ↪ ───       -E1R                   ─────       -E2R                ⎟           ↪
# ↪ T         ─────                    T         ─────               ⎟           ↪
# ↪             T     A₂⋅Cb⋅E2R⋅dH₂⋅ℯ              T     3⋅F     UA  ⎟    6⋅F⋅UA ↪
# ↪ ─── + A₁⋅ℯ      + ──────────────────── + A₂⋅ℯ      + ─── + ──────⎟  - ────── ↪
# ↪                             2                         V    Cp⋅V⋅ρ⎟        2  ↪
# ↪                         Cp⋅T ⋅ρ                                  ⎠    Cp⋅V ⋅ ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                            3                                 ↪
# ↪           -E2R                            ⎞    ⎛                 -E1R        ↪
# ↪           ─────       -E2R                ⎟    ⎜                 ─────       ↪
# ↪             T         ─────               ⎟    ⎜                   T         ↪
# ↪ ⋅E2R⋅dH₂⋅ℯ              T     3⋅F     UA  ⎟    ⎜9⋅A₁⋅Ca⋅E1R⋅dH₁⋅ℯ            ↪
# ↪ ─────────────── + A₂⋅ℯ      + ─── + ──────⎟  - ⎜────────────────────── + 9⋅A ↪
# ↪      2                         V    Cp⋅V⋅ρ⎟    ⎜           2                 ↪
# ↪  Cp⋅T ⋅ρ                                  ⎠    ⎝       Cp⋅T ⋅ρ               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ─                                                                            ↪
# ↪                                                                              ↪
# ↪ ρ                                                                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                             -E2R                               ⎞ ⎛           ↪
# ↪    -E1R                     ─────         -E2R                 ⎟ ⎜           ↪
# ↪    ─────                      T           ─────                ⎟ ⎜           ↪
# ↪      T     9⋅A₂⋅Cb⋅E2R⋅dH₂⋅ℯ                T     27⋅F    9⋅UA ⎟ ⎜A₁⋅A₂⋅Ca⋅E ↪
# ↪ ₁⋅ℯ      + ────────────────────── + 9⋅A₂⋅ℯ      + ──── + ──────⎟⋅⎜────────── ↪
# ↪                       2                            V     Cp⋅V⋅ρ⎟ ⎜           ↪
# ↪                   Cp⋅T ⋅ρ                                      ⎠ ⎝           ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪         -E1R   -E2R                      -E1R   -E2R                      -E ↪
# ↪         ─────  ─────                     ─────  ─────                     ── ↪
# ↪           T      T                         T      T                          ↪
# ↪ 1R⋅dH₁⋅ℯ     ⋅ℯ        A₁⋅A₂⋅Ca⋅E1R⋅dH₂⋅ℯ     ⋅ℯ        A₁⋅A₂⋅Cb⋅E2R⋅dH₂⋅ℯ   ↪
# ↪ ──────────────────── + ────────────────────────────── + ──────────────────── ↪
# ↪      2                                2                                2     ↪
# ↪  Cp⋅T ⋅ρ                          Cp⋅T ⋅ρ                          Cp⋅T ⋅ρ   ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ 1R   -E2R                                             -E1R            -E1R   ↪
# ↪ ───  ─────          -E1R   -E2R                       ─────           ─────  ↪
# ↪ T      T            ─────  ─────                        T               T    ↪
# ↪    ⋅ℯ                 T      T     2⋅A₁⋅Ca⋅E1R⋅F⋅dH₁⋅ℯ        2⋅A₁⋅F⋅ℯ       ↪
# ↪ ────────── + A₁⋅A₂⋅ℯ     ⋅ℯ      + ──────────────────────── + ─────────────  ↪
# ↪                                               2                     V        ↪
# ↪                                           Cp⋅T ⋅V⋅ρ                          ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪ ____________________________________________________________________________ ↪
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          -E1R                       -E2R            -E2R           -E2R      ↪
# ↪          ─────                      ─────           ─────          ─────     ↪
# ↪            T                          T               T              T       ↪
# ↪   A₁⋅UA⋅ℯ        2⋅A₂⋅Cb⋅E2R⋅F⋅dH₂⋅ℯ        2⋅A₂⋅F⋅ℯ        A₂⋅UA⋅ℯ        3 ↪
# ↪ + ──────────── + ──────────────────────── + ───────────── + ──────────── + ─ ↪
# ↪      Cp⋅V⋅ρ                 2                     V            Cp⋅V⋅ρ        ↪
# ↪                         Cp⋅T ⋅V⋅ρ                                            ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ...
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪ ___________________________________________                                  ↪
# ↪                                          2                                   ↪
# ↪                                         ⎞                                    ↪
# ↪       -E2R                  ⎞           ⎟                                    ↪
# ↪       ─────                 ⎟           ⎟                                    ↪
# ↪         T        2          ⎟       2   ⎟                                    ↪
# ↪ ₂⋅UA⋅ℯ        3⋅F    2⋅F⋅UA ⎟   27⋅F ⋅UA⎟     ⎛               -E1R           ↪
# ↪ ─────────── + ──── + ───────⎟ + ────────⎟     ⎜               ─────       -E ↪
# ↪   Cp⋅V⋅ρ        2        2  ⎟       3   ⎟     ⎜                 T         ── ↪
# ↪                V     Cp⋅V ⋅ρ⎠   Cp⋅V ⋅ρ ⎠     ⎜A₁⋅Ca⋅E1R⋅dH₁⋅ℯ               ↪
# ↪ ─────────────────────────────────────────── + ⎜──────────────────── + A₁⋅ℯ   ↪
# ↪                                               ⎜          2                   ↪
# ↪                                               ⎝      Cp⋅T ⋅ρ                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                           ⎛                  ↪
# ↪                                                           ⎜                  ↪
# ↪                                                       3   ⎜                  ↪
# ↪                      -E2R                            ⎞    ⎜9⋅A₁⋅Ca⋅E1R⋅dH₁⋅ℯ ↪
# ↪ 1R                   ─────       -E2R                ⎟    ⎜───────────────── ↪
# ↪ ───                    T         ─────               ⎟    ⎜           2      ↪
# ↪ T     A₂⋅Cb⋅E2R⋅dH₂⋅ℯ              T     3⋅F     UA  ⎟    ⎝       Cp⋅T ⋅ρ    ↪
# ↪     + ──────────────────── + A₂⋅ℯ      + ─── + ──────⎟  - ────────────────── ↪
# ↪                 2                         V    Cp⋅V⋅ρ⎟                       ↪
# ↪             Cp⋅T ⋅ρ                                  ⎠                       ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ -E1R                                   -E2R                               ⎞  ↪
# ↪ ─────         -E1R                     ─────         -E2R                 ⎟  ↪
# ↪   T           ─────                      T           ─────                ⎟  ↪
# ↪                 T     9⋅A₂⋅Cb⋅E2R⋅dH₂⋅ℯ                T     27⋅F    9⋅UA ⎟  ↪
# ↪ ───── + 9⋅A₁⋅ℯ      + ────────────────────── + 9⋅A₂⋅ℯ      + ──── + ──────⎟⋅ ↪
# ↪                                  2                            V     Cp⋅V⋅ρ⎟  ↪
# ↪                              Cp⋅T ⋅ρ                                      ⎠  ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ⎛                  -E1R   -E2R                      -E1R   -E2R              ↪
# ↪ ⎜                  ─────  ─────                     ─────  ─────             ↪
# ↪ ⎜                    T      T                         T      T               ↪
# ↪ ⎜A₁⋅A₂⋅Ca⋅E1R⋅dH₁⋅ℯ     ⋅ℯ        A₁⋅A₂⋅Ca⋅E1R⋅dH₂⋅ℯ     ⋅ℯ        A₁⋅A₂⋅Cb⋅ ↪
# ↪ ⎜────────────────────────────── + ────────────────────────────── + ───────── ↪
# ↪ ⎜               2                                2                           ↪
# ↪ ⎝           Cp⋅T ⋅ρ                          Cp⋅T ⋅ρ                         ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪          -E1R   -E2R                                             -E1R        ↪
# ↪          ─────  ─────          -E1R   -E2R                       ─────       ↪
# ↪            T      T            ─────  ─────                        T         ↪
# ↪ E2R⋅dH₂⋅ℯ     ⋅ℯ                 T      T     2⋅A₁⋅Ca⋅E1R⋅F⋅dH₁⋅ℯ        2⋅A ↪
# ↪ ───────────────────── + A₁⋅A₂⋅ℯ     ⋅ℯ      + ──────────────────────── + ─── ↪
# ↪       2                                                  2                   ↪
# ↪   Cp⋅T ⋅ρ                                            Cp⋅T ⋅V⋅ρ               ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪    2                                                                         ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ____________________________________________________________________________ ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪      -E1R           -E1R                       -E2R            -E2R          ↪
# ↪      ─────          ─────                      ─────           ─────         ↪
# ↪        T              T                          T               T           ↪
# ↪ ₁⋅F⋅ℯ        A₁⋅UA⋅ℯ        2⋅A₂⋅Cb⋅E2R⋅F⋅dH₂⋅ℯ        2⋅A₂⋅F⋅ℯ        A₂⋅UA ↪
# ↪ ────────── + ──────────── + ──────────────────────── + ───────────── + ───── ↪
# ↪    V            Cp⋅V⋅ρ                 2                     V            Cp ↪
# ↪                                    Cp⋅T ⋅V⋅ρ                                 ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪ ──────────────────────────────────────────────────────────────────────────── ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
# ↪                                                                              ↪
#
# ↪ ______________________________________              ⎫
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪   -E2R                  ⎞                           ⎪
# ↪   ─────                 ⎟                           ⎪
# ↪     T        2          ⎟                           ⎪
# ↪ ⋅ℯ        3⋅F    2⋅F⋅UA ⎟                           ⎪
# ↪ ─────── + ──── + ───────⎟                           ⎪
# ↪ ⋅V⋅ρ        2        2  ⎟       2                   ⎪
# ↪            V     Cp⋅V ⋅ρ⎠   27⋅F ⋅UA                ⎪
# ↪ ───────────────────────── + ─────────               ⎪
# ↪                                   3                 ⎪
# ↪                             2⋅Cp⋅V ⋅ρ       UA      ⎪
# ↪ ────────────────────────────────────── - ────────: 1⎬
# ↪                                          3⋅Cp⋅V⋅ρ   ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎪
# ↪                                                     ⎭
